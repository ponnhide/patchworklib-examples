# %%
import sys 
sys.path = ["/Users/hideto/dropbox/HIDETO_MORI.LAB/Experiments/Project/Patchplot/patchworklib"] + sys.path
import patchworklib as pw

# %%
import time
t0 = time.time()
ax_list1 = []
for i in range(5):
    ax_list1.append(pw.Brick(figsize=(2,2), label="ax{}".format(i)))
ax_list2 = []
for i in range(5,10):
    ax_list2.append(pw.Brick(figsize=(2,2), label="ax{}".format(i)))

row1 = pw.stack(ax_list1, operator="|", margin=0.2)
row2 = pw.stack(ax_list2, operator="|", margin=0.2)
stacked_axes = row1/row2 
stacked_axes.savefig("../stack_example.png")

# %%
ax10 = pw.Brick(figsize=(2,2), label="ax10")
stacked_axes = stacked_axes["ax9"]/ax10
stacked_axes.savefig()

# %%
ax11 = pw.Brick(figsize=(2,2), label="ax11")
ax12 = pw.Brick(figsize=(2,2), label="ax12")
ax1112 = (ax11/ax12)
ax1112.savefig()

# %%
ax1112.get_label()
# Out:
# 'Bricks-10'

# %%
#ax11.adjust = False
stacked_axes = stacked_axes["ax7"]/ax1112
stacked_axes.savefig()

# %%
ax13 = pw.Brick(figsize=(2,2), label="ax13")
ax14 = pw.Brick(figsize=(2,2), label="ax14")
ax1314 = (ax13|ax14)
ax1314.savefig()

# %%
ax15 = pw.Brick(figsize=(7,2), label="ax15")
ax15.savefig()

# %%
stacked_axes = stacked_axes["ax4"]|ax15

# %%
stacked_axes.savefig()

# %%
stacked_axes = stacked_axes["ax9"]|ax1314
stacked_axes.savefig()

# %%
ax16 = pw.Brick(figsize=(2,2), label="ax16")
stacked_axes = ax16|stacked_axes["ax5"]
stacked_axes.savefig()

# %%
ax17 = pw.Brick(figsize=(2,2), label="ax17")
ax18 = pw.Brick(figsize=(2,2), label="ax18")
ax1718 = ax17/ax18
stacked_axes = ax1718|stacked_axes[ax1112.get_label()]

# %%
stacked_axes.savefig()

# %%
print(time.time()-t0)
# Out:
# 7.563431024551392
